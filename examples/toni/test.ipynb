# %% [markdown]
# # Test Data

# %%
import qlib
# region in [REG_CN, REG_US]
from qlib.constant import REG_US
provider_uri = "~/.qlib/qlib_data/us_data"  # target_dir
qlib.init(provider_uri=provider_uri, region=REG_US)
# Out:
# [6928:MainThread](2026-01-21 12:39:03,010) INFO - qlib.Initialization - [config.py:452] - default_conf: client.
# [6928:MainThread](2026-01-21 12:39:03,012) INFO - qlib.Initialization - [__init__.py:75] - qlib successfully initialized based on client settings.
# [6928:MainThread](2026-01-21 12:39:03,013) INFO - qlib.Initialization - [__init__.py:77] - data_path={'__DEFAULT_FREQ': PosixPath('/home/toni/.qlib/qlib_data/us_data')}
