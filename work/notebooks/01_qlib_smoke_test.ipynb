# %% [markdown]
# # 01 - Microsoft Qlib smoke test
#
# Este notebook valida tres cosas:
#
# 1. que `qlib` importa correctamente
# 2. que Qlib inicializa con la configuración del proyecto
# 3. si el `provider_uri` ya contiene un dataset operativo

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve()
if ROOT.name == 'notebooks':
    ROOT = ROOT.parent

SRC = ROOT / 'src'
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

ROOT
# Out:
# PosixPath('/home/trodriguez/.openclaw/workspace/qlib')

# %%
from qlib_project.bootstrap import project_summary, validate_qlib_installation

print(project_summary())
# Out:
# Qlib project summary
# - root: /home/trodriguez/.openclaw/workspace/qlib
# - provider_uri: /home/trodriguez/.openclaw/workspace/qlib/data/qlib
# - region: cn
# - benchmark: SH000300
# - universe: csi300
# - frequency: day

# %%
result = validate_qlib_installation()
result
# Out:
# [13590:MainThread](2026-05-09 19:31:12,617) INFO - qlib.Initialization - [config.py:453] - default_conf: client.
# [13590:MainThread](2026-05-09 19:31:14,765) INFO - qlib.Initialization - [__init__.py:82] - qlib successfully initialized based on client settings.
# [13590:MainThread](2026-05-09 19:31:14,767) INFO - qlib.Initialization - [__init__.py:84] - data_path={'__DEFAULT_FREQ': PosixPath('/home/trodriguez/.openclaw/workspace/qlib/data/qlib')}
# {'provider_uri': '/home/trodriguez/.openclaw/workspace/qlib/data/qlib',
#  'region': 'cn',
#  'qlib_module': '/mnt/d/src/qlib/qlib/__init__.py',
#  'init': 'ok',
#  'calendar': 'ok (6381 timestamps)',
#  'provider_file_count': '60918',
#  'dataset_status': 'data files detected'}

# %%
dataset_status = result.get('dataset_status', '')
if 'no dataset files' in dataset_status:
    print('Qlib está bien instalado e inicializa correctamente, pero aún no hay datos cargados en data/qlib/.')
else:
    print('Qlib está bien instalado, inicializa correctamente y ya hay datos detectados en el provider.')
# Out:
# Qlib está bien instalado, inicializa correctamente y ya hay datos detectados en el provider.
